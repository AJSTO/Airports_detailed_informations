# %%
import pandas as pd
import numpy as np
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import DataFrameReader
from pyspark.sql import SQLContext
from pyspark import SparkContext
import re
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from pyspark.sql.functions import col, format_string, date_format, format_number
warnings.filterwarnings('ignore')

# %%
# To connect with PostgreSQL database
password = 'flights'
username='flights'
host = '127.0.0.1'
port = '5440'
db_name = 'air'
PATH_TO_JAR_FILE = 'postgres_driver_JDBC/postgresql-42.5.1.jar'

# %%
spark = SparkSession.builder \
        .appName('Flights_data') \
        .config("spark.jars", PATH_TO_JAR_FILE) \
        .config("spark.driver.memory", "4g") \
        .getOrCreate()
# Out:
# 23/02/11 14:03:13 WARN Utils: Your hostname, MacBook-Air-Adam.local resolves to a loopback address: 127.0.0.1; using 192.168.198.32 instead (on interface en0)
# 23/02/11 14:03:13 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/02/11 14:03:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/02/11 14:03:14 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# URL connection to postgres database
url = f'jdbc:postgresql://{host}:{port}/{db_name}'

# %%
# aircrafts_data
aircrafts_data_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM aircrafts_data')\
    .option('password',password)\
    .load()

# %%
# airports_data
airports_data_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM airports_data')\
    .option('password',password)\
    .load()

# %%
# boarding_passes
boarding_passes_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM boarding_passes')\
    .option('password',password)\
    .load()

# %%
# bookings
bookings_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM bookings')\
    .option('password',password)\
    .load()

# %%
# flights
flights_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM flights')\
    .option('password',password)\
    .load()

# %%
# seats
seats_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM seats')\
    .option('password',password)\
    .load()

# %%
# ticket_flights
ticket_flights_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM ticket_flights')\
    .option('password',password)\
    .load()

# %%
# tickets
tickets_df = spark.read\
    .format('jdbc')\
    .option('url',url)\
    .option('driver', 'org.postgresql.Driver')\
    .option('dtable', 'tickets')\
    .option('user', username)\
    .option('query', 'SELECT * FROM tickets')\
    .option('password',password)\
    .load()

# %% [markdown]
# ## Simplify airport DataFrame to have only english names of airport and city

# %%
# Airports dataframe schema
airports_data_df.schema
# Out:
# StructType([StructField('airport_code', StringType(), True), StructField('airport_name', StringType(), True), StructField('city', StringType(), True), StructField('coordinates', StringType(), True), StructField('timezone', StringType(), True)])

# %%
# Using RDD to be able using map function
rdd2=airports_data_df.rdd.map(
    lambda x: (
        x.airport_code,
        re.findall(r'"(.*?)"', x.airport_name)[1],
        re.findall(r'"(.*?)"', x.city)[1],
        x.coordinates,
        x.timezone,
        float(re.findall(r'\d+.\d+', x.coordinates)[0]),
        float(re.findall(r'\d+.\d+', x.coordinates)[1])
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "airport_code", "airport_name", "city", "coordinates", "timezone", "long", "lat",
    ]
)
simplify_airport_df = df2

# To pandas which allows us to draw a plot
airports_df = simplify_airport_df.toPandas()

airports_df
# Out:
#     airport_code               airport_name               city  \
# 0            YKS            Yakutsk Airport            Yakutsk
# 1            MJZ              Mirny Airport             Mirnyj
# 2            KHV    Khabarovsk-Novy Airport         Khabarovsk
# 3            PKC           Yelizovo Airport      Petropavlovsk
# 4            UUS  Yuzhno-Sakhalinsk Airport  Yuzhno-Sakhalinsk
# ..           ...                        ...                ...
# 99           MMK           Murmansk Airport           Murmansk
# 100          ABA             Abakan Airport             Abakan
# 101          BAX            Barnaul Airport            Barnaul
# 102          AAQ    Anapa Vityazevo Airport              Anapa
# 103          CNN            Chulman Airport          Neryungri
#
#                                    coordinates          timezone        long  \
# 0        (129.77099609375,62.0932998657226562)      Asia/Yakutsk  129.770996
# ...

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
with plt.style.context(("seaborn", "ggplot")):    
    world.plot(figsize=(18,10),
                   color="white",
                   edgecolor = "grey")
    plt.scatter(airports_df.long, airports_df.lat, s=10, color="blue",)
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title("Airports location of obtained data", fontsize=20)
    plt.show()

# %% [markdown]
# As we can see obtained data is refering only to Russia Federation

# %% [markdown]
# # Delays analyse

# %%
# Dropping NaT values of depatures and arrivals
delay_df = flights_df.dropna(
    how='any', 
    thresh=None, 
    subset=('scheduled_departure', 'scheduled_arrival', 'actual_departure', 'actual_arrival'),
)

# Create df with only city and airport number
city_df = simplify_airport_df.select('airport_code', 'city')

# Adding depature city
delay_city = delay_df.join(city_df,delay_df.departure_airport ==  city_df.airport_code,"leftouter")
delay_city = delay_city.withColumnRenamed("city","depature_city")
delay_city = delay_city.drop("airport_code")
# Adding arrival city
delay_city = delay_city.join(city_df,delay_df.arrival_airport ==  city_df.airport_code,"leftouter")
delay_city = delay_city.withColumnRenamed("city","arrival_city")
delay_city = delay_city.drop("airport_code")

# Average delay per connection calculations in this cell
# Using RDD to be able using map function
rdd2=delay_city.rdd.map(
    lambda x: (
        x.flight_no, x.departure_airport, x.arrival_airport,
        x.depature_city + '-' + x.arrival_city,
        (x.actual_departure - x.scheduled_departure).total_seconds() ,
        (x.actual_arrival - x.scheduled_arrival).total_seconds(),
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "flight_no","departure_airport","arrival_airport", "connection", 
        "departure_delay_seconds", "arrival_delay_seconds",
    ]
)
# Counting average delay per connection
avg_del_per_conn = df2.groupBy("connection") \
            .mean("departure_delay_seconds", "arrival_delay_seconds" )

# Switch to pandas DataFrame
avg_del_per_conn = avg_del_per_conn.toPandas()

# Round values of delays columns
avg_del_per_conn[
    'avg(departure_delay_seconds)'
] = avg_del_per_conn[
    'avg(departure_delay_seconds)'
    ].apply(lambda x: round(x,2))
avg_del_per_conn[
    'avg(arrival_delay_seconds)'
] = avg_del_per_conn[
    'avg(arrival_delay_seconds)'
    ].apply(lambda x: round(x,2))

# Switch seconds to minutes
avg_del_per_conn[
    'avg(departure_delay_minutes)'
] = avg_del_per_conn[
    'avg(departure_delay_seconds)'
    ].apply(lambda x: round(x/60,2))
avg_del_per_conn[
    'avg(arrival_delay_minutes)'
] = avg_del_per_conn[
    'avg(arrival_delay_seconds)'
    ].apply(lambda x: round(x/60,2))

# Description of created DF
avg_del_per_conn.describe()
# Out:
#        avg(departure_delay_seconds)  avg(arrival_delay_seconds)  \
# count                    516.000000                  516.000000
# mean                     763.390659                  763.235581
# std                      193.643798                  194.180484
# min                      156.230000                  138.110000
# 25%                      650.887500                  649.617500
# 50%                      751.725000                  749.075000
# 75%                      865.687500                  863.967500
# max                     1680.000000                 1715.770000
#
#        avg(departure_delay_minutes)  avg(arrival_delay_minutes)
# count                    516.000000                  516.000000
# mean                      12.723178                   12.720717
# std                        3.227399                    3.236191
# min                        2.600000                    2.300000
# 25%                       10.852500                   10.827500
# ...

# %%
# Flight connections with biggest depature delay
biggest_depature_delay = avg_del_per_conn.sort_values(
    by=['avg(departure_delay_minutes)'], 
    ascending=False
).head(15)[
    ['connection', 'avg(departure_delay_minutes)']
]

plt.figure(figsize=(10, 7))
plt.title("Biggest average departure delay in minutes for flight connections from 2016", fontsize=25)
sns.barplot(data = biggest_depature_delay, x = 'connection', y = 'avg(departure_delay_minutes)')
plt.xticks(size=10, rotation=90)
plt.yticks(size=15)
plt.xlabel("Flight connections", fontsize=15)
plt.ylabel("Average delay in minutes", fontsize=15)
plt.show()

# %%
# Flight connections with biggest arrival delay
biggest_arrival_delay = avg_del_per_conn.sort_values(
    by=['avg(arrival_delay_minutes)'], 
    ascending=False
).head(15)[
    ['connection', 'avg(arrival_delay_minutes)']
]

plt.figure(figsize=(10, 7))
plt.title("Biggest average arrival delay in minutes for flight connections from 2016", fontsize=25)
sns.barplot(data = biggest_arrival_delay, x = 'connection', y = 'avg(arrival_delay_minutes)')
plt.xticks(size=10, rotation=90)
plt.yticks(size=15)
plt.xlabel("Flight connections", fontsize=15)
plt.ylabel("Average delay in minutes", fontsize=15)
plt.show()

# %% [markdown]
# # Airports with the most flights

# %%
# Creating df with airports names
airports_names = simplify_airport_df.select('airport_code', 'airport_name')

# New df to handle with airports with the most flights
most_flights = flights_df
# Adding depature airport
most_flights = most_flights.join(airports_names,delay_df.departure_airport ==  city_df.airport_code,"leftouter")
most_flights = most_flights.withColumnRenamed("airport_name","depature_airport_name")
most_flights = most_flights.drop("airport_code")

# Counting airports with the most depatures
most_depatures = most_flights.groupBy('depature_airport_name')\
            .count()

most_depatures = most_depatures.toPandas().sort_values(
    by=['count'], 
    ascending=False
).head(15)

plt.figure(figsize=(10, 7))
plt.title("Airports with the most depatures from 2016", fontsize=25)
sns.barplot(data = most_depatures, x = 'depature_airport_name', y = 'count')
plt.xticks(size=10, rotation=90)
plt.yticks(size=15)
plt.xlabel("Airports", fontsize=15)
plt.ylabel("Sum of flights", fontsize=15)
plt.show()

# %% [markdown]
# # Checking available seats per model

# %%
# Checking how many seats has each aircraft
aircraft_num_of_seats = seats_df.groupBy('aircraft_code')\
            .count()

# Using RDD to be able using map function to get proper name of aircraft model
rdd2=aircrafts_data_df.rdd.map(
    lambda x: (
        x.aircraft_code,
        re.findall(r'"(.*?)"', x.model)[1],
        x.range
)
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "aircraft_code", "model", "range",
    ]
)
aircrafts = df2

# Combine aircrafts dataframe and aircraft_num_of_seats dataframe
aircrafts = aircrafts.join(aircraft_num_of_seats,aircrafts.aircraft_code ==  aircraft_num_of_seats.aircraft_code,"leftouter")
aircrafts = aircrafts.withColumnRenamed("count","seats_available")
aircrafts = aircrafts.drop("aircraft_code")

# Small barplot to show aircraft available sets 
aircrafts = aircrafts.toPandas()
plt.figure(figsize=(10, 7))
plt.title("Available seats per model", fontsize=25)
sns.barplot(data = aircrafts.sort_values(by='seats_available', ascending=False), x = 'model', y = 'seats_available')
plt.xticks(size=10, rotation=45)
plt.yticks(size=15)
plt.xlabel("Model", fontsize=15)
plt.ylabel("Available seats ", fontsize=15)
plt.show()

# %% [markdown]
# # Checking aircraft model range

# %%
# Small barplot to show aircraft range by model
plt.figure(figsize=(10, 7))
plt.title("Aircraft range by model", fontsize=25)
sns.barplot(data = aircrafts.sort_values(by='range', ascending=False), x = 'model', y = 'range')
plt.xticks(size=10, rotation=45)
plt.yticks(size=15)
plt.xlabel("Model", fontsize=15)
plt.ylabel("Range", fontsize=15)
plt.show()

# %% [markdown]
# # Most used aircraft models

# %%
# Simplify aircraft dataframe
# Using RDD to be able using map function to get proper name of aircraft model
rdd2=aircrafts_data_df.rdd.map(
    lambda x: (
        x.aircraft_code,
        re.findall(r'"(.*?)"', x.model)[1],
        x.range
)
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "aircraft_code", "model", "range",
    ]
)
aircrafts = df2

# Counting flights by aircraft_code
aircrafts_flights = flights_df.groupBy('aircraft_code')\
            .count()

aircrafts_flights.show()
# Out:
# +-------------+-----+
# |aircraft_code|count|
# +-------------+-----+
# |          SU9|55213|
# |          733| 8263|
# |          773| 3960|
# |          319| 8032|
# |          CN1|60196|
# |          763| 7920|
# |          321|12672|
# |          CR2|58611|
# +-------------+-----+

# %%
# Joining aircrafts df and flights_df
aircraft_use = aircrafts_flights.join(aircrafts,aircrafts_flights.aircraft_code ==  aircrafts.aircraft_code,"leftouter")
aircraft_use = aircraft_use.drop("aircraft_code")
aircraft_use = aircraft_use.drop("range")

plt.figure(figsize=(10, 7))
aircraft_use = aircraft_use.toPandas()
plt.title("Usage of aircrafts in flights from 2016", fontsize=25)
sns.barplot(data = aircraft_use.sort_values(by=['count'], ascending=False), x = 'model', y = 'count')
plt.xticks(size=10, rotation=45)
plt.yticks(size=15)
plt.xlabel("Model", fontsize=15)
plt.ylabel("Total amount of flights", fontsize=15)
plt.show()

# %% [markdown]
# # Checking the number of occupied seats per flight connection

# %%
# Checking how many seats has each aircraft
aircraft_num_of_seats = seats_df.groupBy('aircraft_code')\
            .count()

# Create df with only city and airport number
city_df = simplify_airport_df.select('airport_code', 'city')

# Simplified flights connections
connection = flights_df.select('flight_id', 'departure_airport', 'arrival_airport', 'aircraft_code')

# Adding depature city
connection = connection.join(city_df,delay_df.departure_airport ==  city_df.airport_code,"leftouter")
connection = connection.withColumnRenamed("city","depature_city")
connection = connection.drop("airport_code")
# Adding arrival city
connection = connection.join(city_df,delay_df.arrival_airport ==  city_df.airport_code,"leftouter")
connection = connection.withColumnRenamed("city","arrival_city")
connection = connection.drop("airport_code")

# Using RDD to be able using map function to create city flight connections
rdd2=connection.rdd.map(
    lambda x: (
        x.flight_id,
        x.depature_city + '-' + x.arrival_city,
        x.aircraft_code,
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "flight_id", "connection", "aircraft_code", 
    ]
)

connection =df2

# Num of occupied seats per flight
occ_seats_per_flight = boarding_passes_df.groupBy('flight_id')\
            .count()

# Joining occ_seats_per_flight with connection and next to aircraft_num_of_seats
combined_df = connection.join(occ_seats_per_flight,connection.flight_id ==  occ_seats_per_flight.flight_id,"leftouter")
combined_df = combined_df.withColumnRenamed("count","seats_occupied")
combined_df = combined_df.drop("flight_id")

combined_df = combined_df.join(aircraft_num_of_seats,combined_df.aircraft_code ==  aircraft_num_of_seats.aircraft_code,"leftouter")
combined_df = combined_df.withColumnRenamed("count","seats_available")
combined_df = combined_df.drop("aircraft_code")

# Counting percentage of occupied seats per flight connection
percentage_of_seats_locked = combined_df.groupBy('connection')\
            .sum('seats_occupied', 'seats_available')
percentage_of_seats_locked = percentage_of_seats_locked.withColumnRenamed("sum(seats_occupied)","seats_occupied")
percentage_of_seats_locked = percentage_of_seats_locked.withColumnRenamed("sum(seats_available)","seats_available")

# Dropping null values
percentage_of_seats_locked = percentage_of_seats_locked.dropna(
    how='any', 
    thresh=None, 
    subset=('seats_occupied', ),
)

# Using RDD to be able using map function to create city flight connections
rdd2=percentage_of_seats_locked.rdd.map(
    lambda x: (
        x.connection,
        round((x.seats_occupied / x.seats_available)*100,2),
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "connection", "occupied_percentage", 
    ]
)
percentage_of_seats_locked = df2

# Finally dataframe with percentage of occupied seats 
percentage_of_seats_locked = percentage_of_seats_locked.toPandas()

percentage_of_seats_locked = percentage_of_seats_locked.sort_values(
    by=['occupied_percentage'], 
    ascending=False
)

plt.figure(figsize=(10, 7))
plt.title("Percentage of occupied seats per flight connection TOP15", fontsize=25)
sns.barplot(data = percentage_of_seats_locked.head(15), x = 'connection', y = 'occupied_percentage')
plt.xticks(size=10, rotation=90)
plt.yticks(size=15)
plt.xlabel("Flight connections", fontsize=15)
plt.ylabel("Percentage of occupied seats", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.title("Distribution of occupied seats per flight connection", fontsize=25)
sns.barplot(data = percentage_of_seats_locked, x = 'connection', y = 'occupied_percentage')
plt.xticks(size=10, rotation=90)
plt.yticks(size=15)
plt.xlabel("Flight connections", fontsize=15)
plt.tick_params(labelbottom=False)
plt.ylabel("Percentage of occupied seats", fontsize=15)
plt.show()

# %% [markdown]
# # Chart of realised flights in range of time

# %%
# Using RDD to change scheduled depature to YYYY-MM-DD
rdd2=flights_df.rdd.map(
    lambda x: (
        x.flight_id,
        str(x.scheduled_departure).split(' ')[0]
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "flight_id", "str_date", 
    ]
)
flights_by_day = df2

# Counting flights by day
flights_by_day = flights_by_day.groupBy('str_date')\
            .count()

flights_by_day = flights_by_day.toPandas()

# Getting unique months from dataframe and create custom labels of x-ticks (middle of each month which is 15th day)
dates = list(flights_by_day.str_date.apply(lambda x: x[:7]+'-15').unique()) 

plt.figure(figsize=(20, 10))
sns.lineplot(data=flights_by_day.sort_values(by='str_date'),x='str_date',y='count',
            legend='full')
plt.title("Flights by date", fontsize=30)
plt.xticks(fontsize=10, ticks=sorted(dates))
plt.xlabel("Date of flight", fontsize=15)
plt.ylabel("Number of flights", fontsize=15)
plt.grid()

# %%
# Before next comuptation cache need to be cleared
spark.catalog.clearCache()

# %% [markdown]
# # Chart of transported passengers in range of time

# %%
# Using RDD to change scheduled depature to YYYY-MM-DD
rdd2=flights_df.rdd.map(
    lambda x: (
        x.flight_id,
        str(x.scheduled_departure).split(' ')[0]
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "flight_id", "str_date", 
    ]
)
flights_by_day = df2

# Num of passengers per flight
passengers_per_flight = boarding_passes_df.groupBy('flight_id')\
            .count()
passengers_per_flight = passengers_per_flight.withColumnRenamed("flight_id","id_flight")

# Joining passengers per flight with flights by day
num_of_passengers = flights_by_day.join(
    passengers_per_flight,flights_by_day.flight_id ==  passengers_per_flight.id_flight,"leftouter"
)

num_of_passengers = num_of_passengers.dropna(how='any', subset=('id_flight', 'count'))

# Counting passsengers by day
num_of_passengers = num_of_passengers.groupBy('str_date')\
            .sum('count')

num_of_passengers = num_of_passengers.toPandas()

# Getting unique months from dataframe and create custom labels of x-ticks (middle of each month which is 15th day)
dates = list(num_of_passengers.str_date.apply(lambda x: x[:7]+'-15').unique()) 

plt.figure(figsize=(20, 10))
sns.lineplot(data=num_of_passengers.sort_values(by='str_date'),x='str_date',y='sum(count)',
            legend='full')
plt.title("Passengers per date", fontsize=30)
plt.xticks(fontsize=10, ticks=sorted(dates))
plt.xlabel("Date of flight", fontsize=15)
plt.ylabel("Number of passengers", fontsize=15)
plt.grid()

# %% [markdown]
# # Chart of served passengers per airport for biggest airports

# %%
# Creating df with airports names
airports_names = simplify_airport_df.select('airport_code', 'airport_name')

# Num of passengers per flight
passengers_per_flight = boarding_passes_df.groupBy('flight_id')\
            .count()
passengers_per_flight = passengers_per_flight.withColumnRenamed("flight_id","id_flight")

# Joining passengers per flight with flights dataframe with airport code
num_of_passengers = flights_df.join(
    passengers_per_flight,flights_df.flight_id ==  passengers_per_flight.id_flight,"leftouter"
)

# Joining passengers per flight with flights dataframe with airport code
num_of_passengers = num_of_passengers.join(
    simplify_airport_df,num_of_passengers.departure_airport ==  simplify_airport_df.airport_code,"leftouter"
)

# Counting passsengers by airport
num_of_passengers = num_of_passengers.groupBy('airport_name')\
            .sum('count')

num_of_passengers = num_of_passengers.toPandas()

num_of_passengers = num_of_passengers.dropna(how='all', subset='sum(count)')

plt.figure(figsize=(20, 10))
sns.barplot(data=num_of_passengers.sort_values(by='sum(count)')[::-1][:15],x='airport_name',y='sum(count)',
            )
plt.title("Passengers per airport (TOP15) from 2016", fontsize=30)
plt.xticks(fontsize=10, rotation=90)
plt.xlabel("Airport", fontsize=15)
plt.ylabel("Number of passengers", fontsize=15)
plt.ticklabel_format(style='plain', axis='y')
plt.grid()

# %% [markdown]
# # Served passengers per airport on world map from 2016

# %%
# Select from simplified airport df only columns: airport_name, long, lat
airports_with_coord = simplify_airport_df.select(
    'airport_code', 'airport_name', 'long', 'lat'
)

# Num of passengers per flight
passengers_per_flight = boarding_passes_df.groupBy('flight_id')\
            .count()
passengers_per_flight = passengers_per_flight.withColumnRenamed("flight_id","id_flight")

# Joining passengers per flight with flights dataframe with flights dataframe with airport
num_of_passengers = flights_df.join(
    passengers_per_flight,flights_df.flight_id ==  passengers_per_flight.id_flight,"leftouter"
)

# Joining passengers per flight with flights dataframe with airport code
num_of_passengers = num_of_passengers.join(
    airports_with_coord,num_of_passengers.departure_airport ==  airports_with_coord.airport_code,"leftouter"
)

# Counting passsengers by airport coordinates
num_of_passengers = num_of_passengers.groupBy('long', 'lat')\
            .sum('count')

num_of_passengers = num_of_passengers.toPandas()

world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
with plt.style.context(("seaborn", "ggplot")):    
    world.plot(figsize=(20,15),
                   color="white",
                   edgecolor = "grey")
    plt.scatter(
        num_of_passengers.long, num_of_passengers.lat, 
        s=num_of_passengers['sum(count)']/1000, color="blue",
        alpha=0.5,
    )
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title("Served passengers per airport on map from 2016", fontsize=30)
    plt.xlim([0, 185])
    plt.ylim([25, 100])
    plt.show()

# %% [markdown]
# # Flights per airport on map from 2016

# %%
# New df to handle with airports with the most flights
most_flights = flights_df
# Adding depature airport
most_flights = most_flights.join(simplify_airport_df,delay_df.departure_airport ==  simplify_airport_df.airport_code,"leftouter")
most_flights = most_flights.withColumnRenamed("airport_name","depature_airport_name")
most_flights = most_flights.drop("airport_code")

# Counting passsengers by airport coordinates
most_flights = most_flights.groupBy('long', 'lat')\
            .count()

# To pandas
most_flights = most_flights.toPandas()

world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
with plt.style.context(("seaborn", "ggplot")):    
    world.plot(figsize=(20,15),
                   color="white",
                   edgecolor = "grey")
    plt.scatter(
        most_flights.long, most_flights.lat, 
        s=most_flights['count']/20, color="blue",
        alpha=0.5,
    )
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title("Flights per airport on map from 2016", fontsize=30)
    plt.xlim([0, 185])
    plt.ylim([25, 100])
    plt.show()

# %% [markdown]
# # Chart of booked tickets in range of time

# %%
# Using RDD to change book_date to YYYY-MM-DD
rdd2=bookings_df.rdd.map(
    lambda x: (
        x.book_ref,
        str(x.book_date).split(' ')[0]
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "book_ref", "str_date", 
    ]
)
book_formatted = df2

# Joining bookings dataframe with dates and ticket dataframe
tickets_per_day = tickets_df.join(
    book_formatted,tickets_df.book_ref ==  book_formatted.book_ref,"leftouter"
)

# Counting tickets per day
tickets_per_day = tickets_per_day.groupBy('str_date')\
            .count()
tickets_per_day = tickets_per_day.toPandas()

# Getting unique months from dataframe and create custom labels of x-ticks (middle of each month which is 15th day)
dates = list(tickets_per_day.str_date.apply(lambda x: x[:7]+'-15').unique()) 

plt.figure(figsize=(20, 10))
sns.lineplot(data=tickets_per_day.sort_values(by='str_date'),x='str_date',y='count',
            legend='full')
plt.title("Booked tickets per date", fontsize=30)
plt.xticks(fontsize=10, ticks=sorted(dates)[1:])
plt.xlabel("Date of booking", fontsize=15)
plt.ylabel("Number of tickets bought", fontsize=15)
plt.grid()

# %% [markdown]
# # How far in advance are flights booked

# %%
# Before next comuptation cache need to be cleared
spark.catalog.clearCache()

# Joining booking df with ticket df
df = bookings_df.join(
    tickets_df ,tickets_df.book_ref ==  bookings_df.book_ref,"leftouter"
)

df = df.select('ticket_no', 'book_date')

# Joining combined df with ticket flights df
df = df.join(
    ticket_flights_df ,df.ticket_no ==  ticket_flights_df.ticket_no,"leftouter"
)

df = df.select('flight_id', 'book_date')

# Joining combined df with ticket flights df
df = df.join(
    flights_df ,df.flight_id ==  flights_df.flight_id,"leftouter"
)

df = df.select('book_date', 'scheduled_departure')

# Using RDD to change book_date to YYYY-MM-DD
rdd2=df.rdd.map(
    lambda x: (
        (x.scheduled_departure - x.book_date).total_seconds()/86400 ,
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "book_difference", 
    ]
)
book_difference = df2

# Difference beetwen booking date and depature in days

book_difference.describe(['book_difference']).show()
# Out:
# [Stage 139:==================================================>      (8 + 1) / 9]
# +-------+------------------+
# |summary|   book_difference|
# +-------+------------------+
# |  count|           8391852|
# |   mean|   20.140624766142|
# | stddev| 5.545189048899918|
# |    min|3.3006944444444444|
# |    max|53.330555555555556|
# +-------+------------------+

# %% [markdown]
# # Description about total price of booking in RUB

# %%
bookings_df.describe(['total_amount']).show()
# Out:
# [Stage 146:>                                                        (0 + 1) / 1]
# +-------+-----------------+
# |summary|     total_amount|
# +-------+-----------------+
# |  count|          2111110|
# |   mean|     79299.069731|
# | stddev|77715.42738380656|
# |    min|          3400.00|
# |    max|       1308700.00|
# +-------+-----------------+

# %% [markdown]
# # Description about tickets per booking

# %%
tick = tickets_df.withColumnRenamed("book_ref","ref_book")

avg_tickets_per_booking = bookings_df.join(tick,bookings_df.book_ref ==  tick.ref_book,"leftouter")

avg_tickets_per_booking = avg_tickets_per_booking.groupBy('book_ref')\
            .count()

avg_tickets_per_booking.describe(['count']).show()
# Out:
# [Stage 153:=======>                                                 (1 + 7) / 8]
# +-------+------------------+
# |summary|             count|
# +-------+------------------+
# |  count|           2111110|
# |   mean|1.3973014196323261|
# | stddev|0.5977023296892091|
# |    min|                 1|
# |    max|                 5|
# +-------+------------------+

# %% [markdown]
# # Average flights per year per passenger

# %%
# Before next comuptation cache need to be cleared
spark.catalog.clearCache()

# Joining ticket df with ticket flights df
avg_flight_per_passenger = tickets_df.join(
    ticket_flights_df,tickets_df.ticket_no ==  ticket_flights_df.ticket_no,"leftouter"
)

avg_flight_per_passenger = avg_flight_per_passenger.select('flight_id', 'passenger_id')

# Joining df with flight id and passenger id to flights df
avg_flight_per_passenger = avg_flight_per_passenger.join(
    flights_df,avg_flight_per_passenger.flight_id ==  flights_df.flight_id,"leftouter"
)

avg_flight_per_passenger = avg_flight_per_passenger.select('passenger_id', 'scheduled_departure')

# Using RDD to change scheduled depature to YYYY-MM-DD
rdd2=avg_flight_per_passenger.rdd.map(
    lambda x: (
        x.passenger_id,
        str(x.scheduled_departure).split(' ')[0][:4]
    )
)
# Return do Pyspark DataFrame
df2=rdd2.toDF(
    [
        "passenger_id", "year", 
    ]
)
avg_flight_per_passenger = df2



avg_flight_per_passenger = avg_flight_per_passenger.groupBy("passenger_id", "year")\
                                .count()

avg_flight_per_passenger.groupBy('year').mean().show()
# Out:
# [Stage 168:==================================================>      (8 + 1) / 9]
# +----+------------------+
# |year|        avg(count)|
# +----+------------------+
# |2016|2.7506243300754045|
# |2017|2.8014928399677204|
# +----+------------------+

# %% [markdown]
# # Seats occupied per fare conditions per flight

# %%
# Seat numbers per fare conditions per aircraft
seats = seats_df.withColumnRenamed(
    "aircraft_code", "aircraft_c"
)
seats_per_aircraft = seats.groupBy('aircraft_c', 'fare_conditions')\
            .count()
# Filtering 
seats_comfort = seats_per_aircraft.filter(
    seats_per_aircraft['fare_conditions'] == 'Comfort'
)
seats_bussines = seats_per_aircraft.filter(
    seats_per_aircraft['fare_conditions'] == 'Business'
)
seats_economy = seats_per_aircraft.filter(
    seats_per_aircraft['fare_conditions'] == 'Economy'
)
seats_comfort = seats_comfort.withColumnRenamed(
    'count', 'seats_comfort'
).drop('fare_conditions')
seats_bussines = seats_bussines.withColumnRenamed(
    'count', 'seats__bussines'
).drop('fare_conditions').withColumnRenamed(
    'aircraft_c', 'aircraft_c1'
)
seats_economy = seats_economy.withColumnRenamed(
    'count', 'seats_economy'
).drop('fare_conditions').withColumnRenamed(
    'aircraft_c', 'aircraft_c2'
)
seats = seats_comfort.join(
    seats_bussines, 
    seats_comfort.aircraft_c == seats_bussines.aircraft_c1,
    "leftouter"
)
seats = seats.join(
    seats_economy, 
    seats.aircraft_c == seats_economy.aircraft_c2,
    "leftouter"
)

seats = seats.join(
    aircrafts_data_df, 
    seats.aircraft_c == aircrafts_data_df.aircraft_code,
    "leftouter"
)
seats = seats.select(
    'aircraft_code', 'seats_comfort', 'seats__bussines', 'seats_economy'
)

# Passengers per fare conditions per aircraft
passengers = ticket_flights_df.groupBy('flight_id', 'fare_conditions')\
            .count()
# Filtering 
passengers_comfort = passengers.filter(passengers['fare_conditions'] == 'Comfort')
passengers_bussines = passengers.filter(passengers['fare_conditions'] == 'Business')
passengers_economy = passengers.filter(passengers['fare_conditions'] == 'Economy')
passengers_comfort = passengers_comfort.withColumnRenamed(
    'count', 'passengers_comfort'
).drop('fare_conditions')
passengers_bussines = passengers_bussines.withColumnRenamed(
    'count', 'passengers_bussines'
).drop('fare_conditions').withColumnRenamed(
    'flight_id', 'flight_id1'
)
passengers_economy = passengers_economy.withColumnRenamed(
    'count', 'passengers_economy'
).drop('fare_conditions').withColumnRenamed(
    'flight_id', 'flight_id2'
)
passengers = passengers_comfort.join(
    passengers_bussines, 
    passengers_comfort.flight_id == passengers_bussines.flight_id1,
    "leftouter"
)
passengers = passengers.join(
    passengers_economy, 
    passengers.flight_id == passengers_economy.flight_id2,
    "leftouter"
)
passengers = passengers.select(
    'flight_id', 'passengers_comfort', 'passengers_bussines', 'passengers_economy',
)
passengers.show()
# NOW WILL HAVE PROBLEM WITH SEATS DF WITH COMBINED SEATS FOR E, B, C CLASS
# HAVE TO COLLECT ALL
# Out:
# [Stage 1240:>                                                       (0 + 1) / 1]
# +---------+------------------+-------------------+------------------+
# |flight_id|passengers_comfort|passengers_bussines|passengers_economy|
# +---------+------------------+-------------------+------------------+
# |    22802|                 6|               null|                28|
# |    34778|                42|                 23|               271|
# |    70546|                37|                 26|               253|
# |    50094|                35|                 23|               267|
# |    64016|                44|                 28|               268|
# |    34058|                40|                 21|               225|
# |    63888|                35|                 18|               247|
# |   198404|                36|                 21|               245|
# |    34497|                37|                 26|               262|
# ...

# %%
seats_per_aircraft.show()
# Out:
# +-------------+------------+---------------+
# |aircraft_code|num_of_seats|fare_conditions|
# +-------------+------------+---------------+
# |          319|          20|       Business|
# |          773|          48|        Comfort|
# |          SU9|          12|       Business|
# |          321|         142|        Economy|
# |          773|          30|       Business|
# |          CN1|          12|        Economy|
# |          SU9|          85|        Economy|
# |          CR2|          50|        Economy|
# |          733|         118|        Economy|
# |          763|          30|       Business|
# |          773|         324|        Economy|
# |          321|          28|       Business|
# |          320|          20|       Business|
# |          319|          96|        Economy|
# |          733|          12|       Business|
# |          320|         120|        Economy|
# |          763|         192|        Economy|
# +-------------+------------+---------------+

# %% [markdown]
# # Selected aggregates to work with pySpark

# %% [markdown]
# ## Number of served passengers per airport per day

# %%
# Selecting interesting columns from all neccessary tables
airport_info = airports_data_df.select('airport_code', 'airport_name')
ticket_info = ticket_flights_df.select('flight_id', 'ticket_no')
flights_info = flights_df.select('scheduled_departure', 'flight_id', 'departure_airport')
# Summing number of tickets per flight
tickets_per_flight = ticket_flights_df.groupBy('flight_id')\
            .count()
# Joining tables
passengers_sum = airport_info.join(
    flights_info,airport_info.airport_code ==  flights_info.departure_airport, "leftouter"
)
passengers_sum = passengers_sum.join(
    tickets_per_flight,passengers_sum.flight_id ==  tickets_per_flight.flight_id, "leftouter"
)
# Dropping columns
passengers_sum = passengers_sum.drop('flight_id', 'airport_code', 'departure_airport')
# Date to format DD-MM-YYYY
passengers_sum = passengers_sum.withColumn(
        "date", date_format(col('scheduled_departure'), "dd-MM-yyyy")
    )
# Aggregate passengers per day per airport
passengers_sum = passengers_sum.groupBy('airport_name', 'date')\
            .sum()
# Rename aggregates passengers column
passengers_sum = passengers_sum.withColumnRenamed(
        "sum(count)", "num_of_passengers"
    )
# Airport name to english name
split_col = pyspark.sql.functions.split(passengers_sum['airport_name'], '"')
passengers_sum = passengers_sum.withColumn('airport', split_col.getItem(3))
# Change order of columns
passengers_aggregate = passengers_sum.select('date', 'airport', 'num_of_passengers')

# %% [markdown]
# ## Daily average depature delay per airport

# %%
# Dropping NaT values of depatures and arrivals
flight_info = flights_df.dropna(
    how='any', 
    thresh=None, 
    subset=('scheduled_departure', 'actual_departure'),
)
# Joining tables
delay_per_airport = flight_info.join(
    airports_data_df, flight_info.departure_airport == airports_data_df.airport_code, 
    "leftouter"
)
# Airport name to english name
split_col = pyspark.sql.functions.split(delay_per_airport['airport_name'], '"')
delay_per_airport = delay_per_airport.withColumn('airport', split_col.getItem(3))
# Selecting only necessary info 
delay_per_airport = delay_per_airport.select(
    'scheduled_departure', 'actual_departure', 'airport',
)
# Date to format DD-MM-YYYY
delay_per_airport = delay_per_airport.withColumn(
    "date", date_format(col('scheduled_departure'), "dd-MM-yyyy")
)
# Count delay per flight
delay_per_airport = delay_per_airport.withColumn('delay', 
    delay_per_airport['actual_departure'] - delay_per_airport['scheduled_departure']
)
delay_per_airport = delay_per_airport.select('airport', 'date', 'delay')
delay_per_airport = delay_per_airport.withColumn("delay_seconds",delay_per_airport['delay'].cast('integer'))
# Count mean delay per day per airport per second
delay_per_airport = delay_per_airport.groupBy('airport', 'date')\
    .mean()
# Convert to minutes
delay_per_airport = delay_per_airport.withColumn('avg_delay_min', delay_per_airport['avg(delay_seconds)']/60)
delay_per_airport = delay_per_airport.withColumn(
    "avg_delay_in_minutes",
    format_number("avg_delay_min", 2)
)
delay_per_airport = delay_per_airport.select('date', 'airport', 'avg_delay_in_minutes')

# %% [markdown]
# ## Daily average booking per airport

# %%
# Joining tables
book_per_airport = bookings_df.join(
    tickets_df, bookings_df.book_ref == tickets_df.book_ref, 
    "leftouter"
)
book_per_airport = book_per_airport.join(
    ticket_flights_df, book_per_airport.ticket_no == ticket_flights_df.ticket_no, 
    "leftouter"
)
book_per_airport = book_per_airport.join(
    flights_df, book_per_airport.flight_id == flights_df.flight_id, 
    "leftouter"
)
book_per_airport = book_per_airport.join(
    airports_data_df, book_per_airport.departure_airport == airports_data_df.airport_code,
    "leftouter"
)
# Selecting only needed columns
book_per_airport = book_per_airport.select('total_amount', 'book_date', 'airport_name')
# Airport name to english name
split_col = pyspark.sql.functions.split(book_per_airport['airport_name'], '"')
book_per_airport = book_per_airport.withColumn('airport', split_col.getItem(3))
# Date to format DD-MM-YYYY
book_per_airport = book_per_airport.withColumn(
    "date", date_format(col('book_date'), "dd-MM-yyyy")
)
# Aggregate bookings per day per airport
book_per_airport = book_per_airport.groupBy('airport', 'date')\
            .count()
# Rename aggregates count of bookings column
book_per_airport = book_per_airport.withColumnRenamed(
        "count", "num_of_bookings"
    )
# Set in order
book_per_airport = book_per_airport.select('date', 'airport', 'num_of_bookings')

# %% [markdown]
# ## Daily aggregate of number of flights to arrival airport

# %%
# Joining tables
flights_to_arrival = flights_df.join(
    airports_data_df, flights_df.arrival_airport == airports_data_df.airport_code,
    "leftouter"
)
# Airport name to english name
split_col = pyspark.sql.functions.split(flights_to_arrival['airport_name'], '"')
flights_to_arrival = flights_to_arrival.withColumn('arrival_airport', split_col.getItem(3))
# Date to format DD-MM-YYYY
flights_to_arrival = flights_to_arrival.withColumn(
    "date", date_format(col('scheduled_arrival'), "dd-MM-yyyy")
)
flights_to_arrival = flights_to_arrival.groupBy('arrival_airport', 'date')\
            .count()
# Rename aggregates passengers column
flights_to_arrival = flights_to_arrival.withColumnRenamed(
        "count", "num_of_flights"
    )
flights_to_arrival = flights_to_arrival.select('date', 'arrival_airport', 'num_of_flights')

# %% [markdown]
# ## Daily average flight occupancy per airport

# %%
# Count tickets per flight
tickets_in_flight = ticket_flights_df.groupBy('flight_id')\
            .count()
# Prepare column before merge
tickets_in_flight = tickets_in_flight.withColumnRenamed(
        "count", "num_of_passengers"
    )
# Seat numbers per aircraft
seats = seats_df.withColumnRenamed(
    "aircraft_code", "aircraft_c"
)
seats_per_aircraft = seats.groupBy('aircraft_c')\
            .count()
seats_per_aircraft = seats_per_aircraft.join(
    aircrafts_data_df, seats_per_aircraft.aircraft_c == aircrafts_data_df.aircraft_code,
    "leftouter"
)
# Prepare column before merge
seats_per_aircraft = seats_per_aircraft.withColumnRenamed(
    "count", "num_of_seats"
)
# Joining tables
avg_occupancy = flights_df.join(tickets_in_flight, flights_df.flight_id == tickets_in_flight.flight_id,
    "leftouter"
)
avg_occupancy = avg_occupancy.join(seats_per_aircraft, avg_occupancy.aircraft_code == seats_per_aircraft.aircraft_code,
    "leftouter"
)
avg_occupancy = avg_occupancy.join(
    airports_data_df, avg_occupancy.departure_airport == airports_data_df.airport_code, 
    "leftouter"
)
# Airport name to english name
split_col = pyspark.sql.functions.split(avg_occupancy['airport_name'], '"')
avg_occupancy = avg_occupancy.withColumn('airport', split_col.getItem(3))
# Selecting needed columns
avg_occupancy = avg_occupancy.select('airport', 'scheduled_departure', 'num_of_seats', 'num_of_passengers')
# Count average occupancy per flight per day in %
avg_occupancy = avg_occupancy.withColumn('occupancy_%', 
        (avg_occupancy['num_of_passengers'] / avg_occupancy['num_of_seats']) * 100
)
# Date to format DD-MM-YYYY
avg_occupancy = avg_occupancy.withColumn(
    "date", date_format(col('scheduled_departure'), "dd-MM-yyyy")
)
# Counting average occupancy per day per airport
avg_occupancy = avg_occupancy.groupBy('airport', 'date')\
    .mean()
avg_occupancy = avg_occupancy.withColumn(
    "avg_occupancy_%",
    format_number("avg(occupancy_%)", 2)
)
# Select columns to final aggregate
avg_occupancy = avg_occupancy.select('date', 'airport', 'avg_occupancy_%')
